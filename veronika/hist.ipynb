# %%
import numpy as np

from tqdm import tqdm

import itertools

Nx = 512
Ny = 512
Nz = 120

I3_lte = np.zeros((5, Nx * Ny, Nz))
I3_nlt = np.zeros((5, Nx * Ny, Nz))
Is_lte = np.zeros((5, Nx * Ny, Nz))
Is_nlt = np.zeros((5, Nx * Ny, Nz))

mu = ['10', '8', '6', '4', '2']

for i in tqdm(range(5)):

    I3_lte[i, :, :] = np.load('./spec/G2V.300G.627321.1.lte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz) * 1e+7
    I3_nlt[i, :, :] = np.load('./spec/G2V.300G.627321.1.nlte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz) * 1e+7
    Is_lte[i, :, :] = np.load('./spec/G2V.ssd.222809.1.lte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz) * 1e+7
    Is_nlt[i, :, :] = np.load('./spec/G2V.ssd.222809.1.nlte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz) * 1e+7

    for j, k in itertools.product(range(Nx * Ny), range(Nz)):
        
        if I3_lte[i, j, k] == 0.0: I3_lte[i, j, k] = np.nan
        if I3_nlt[i, j, k] == 0.0: I3_nlt[i, j, k] = np.nan
        if Is_lte[i, j, k] == 0.0: Is_lte[i, j, k] = np.nan
        if Is_nlt[i, j, k] == 0.0: Is_nlt[i, j, k] = np.nan
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [03:10<00:00, 38.07s/it]

# %%
import numpy as np

from tqdm import tqdm

import itertools

Nx = 512
Ny = 512
Nz = 120

I3_lte = np.zeros((5, Nx * Ny, Nz))
I3_nlt = np.zeros((5, Nx * Ny, Nz))
Is_lte = np.zeros((5, Nx * Ny, Nz))
Is_nlt = np.zeros((5, Nx * Ny, Nz))

mu = ['10', '8', '6', '4', '2']

for i in tqdm(range(5)):

    I3_lte[i, :, :] = np.load('./spec/G2V.300G.627321.1.lte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz)
    I3_nlt[i, :, :] = np.load('./spec/G2V.300G.627321.1.nlte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz)
    Is_lte[i, :, :] = np.load('./spec/G2V.ssd.222809.1.lte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz)
    Is_nlt[i, :, :] = np.load('./spec/G2V.ssd.222809.1.nlte.' + mu[i] + '.npz')['I'].reshape(Nx * Ny, Nz)

    for j, k in itertools.product(range(Nx * Ny), range(Nz)):
        
        if I3_lte[i, j, k] == 0.0: I3_lte[i, j, k] = np.nan
        if I3_nlt[i, j, k] == 0.0: I3_nlt[i, j, k] = np.nan
        if Is_lte[i, j, k] == 0.0: Is_lte[i, j, k] = np.nan
        if Is_nlt[i, j, k] == 0.0: Is_nlt[i, j, k] = np.nan
# Out:
# 100%|███████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████████| 5/5 [03:03<00:00, 36.70s/it]

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

plt.rcParams.update({'font.size': 12})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

for j in tqdm(range(Nz)):
    
    plt.close('all')

    fig, ax = plt.subplots(nrows = 5, ncols = 2, figsize = (15, 25))

    plt.subplots_adjust(wspace = 0.02)

    for i in range(5):
    
        ax[i, 1].yaxis.set_ticklabels([])
    
        ax[i, 0].hist(I3_lte[i, :, j], color = 'k', bins = nbins, histtype = 'step', density = True, label = 'LTE')
        ax[i, 0].hist(I3_nlt[i, :, j], color = 'r', bins = nbins, histtype = 'step', density = True, label = 'NLTE')

        ax[i, 1].hist(Is_lte[i, :, j], color = 'k', bins = nbins, histtype = 'step', density = True)
        ax[i, 1].hist(Is_nlt[i, :, j], color = 'r', bins = nbins, histtype = 'step', density = True)
    
        ax[i, 1].set_xlim(0.002,)
        
        if j <= 30 and i < 4:
            
            ax[i, 1].set_xlim(0.002, 1.0)
            
        if j <= 20 and i < 4:
            
            ax[i, 1].set_xlim(0.002, 0.4)
    
        ax[i, 0].set_xlim(ax[i, 1].get_xlim())
        ax[i, 0].set_ylim(ax[i, 1].get_ylim())
    
        ax[i, 0].set_xlabel(r'Intensity, cgs $\times 10^7$')
        ax[i, 1].set_xlabel(r'Intensity, cgs $\times 10^7$')
    
        ax[i, 0].set_ylabel(r'Density = $N / N_\mathrm{tot} / \Delta$, $\mu = $' + mu[i])
    
    leg = ax[0, 0].legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 12.5})
    
    ax[0, 0].set_title('300G')
    ax[0, 1].set_title('SSD')
    
    pdfs += '/fig/hist/' + str(j) + '.pdf '

    plt.savefig('./fig/hist/' + str(j) + '.pdf', bbox_inches = 'tight')
    
os.system('pdftk ' + pdfs + ' output ./fig/hist/overall.pdf')
# Out:
# 100%|██████████| 120/120 [06:11<00:00,  2.81s/it]
# 0

# %%
Nz = 120

I3_lte_mean = np.zeros((5, Nz))
I3_nlt_mean = np.zeros((5, Nz))
Is_lte_mean = np.zeros((5, Nz))
Is_nlt_mean = np.zeros((5, Nz))

w = np.arange(180, 300, 1) + 0.5

mu = ['2', '4', '6', '8', '10']

for i in range(5):

    I3_lte_mean[i, :] = np.load('./mean_spec/G2V.300G.627321.1.lte.' + mu[i] + '.npz')['I']
    I3_nlt_mean[i, :] = np.load('./mean_spec/G2V.300G.627321.1.nlte.' + mu[i] + '.npz')['I']
    Is_lte_mean[i, :] = np.load('./mean_spec/G2V.ssd.222809.1.lte.' + mu[i] + '.npz')['I']
    Is_nlt_mean[i, :] = np.load('./mean_spec/G2V.ssd.222809.1.nlte.' + mu[i] + '.npz')['I']

# %%
Nz = 120

I3_lte_mean = np.zeros((5, Nz))
I3_nlt_mean = np.zeros((5, Nz))
Is_lte_mean = np.zeros((5, Nz))
Is_nlt_mean = np.zeros((5, Nz))

w = np.arange(180, 300, 1) + 0.5

mu = ['2', '4', '6', '8', '10']

for i in range(5):

    I3_lte_mean[i, :] = np.load('./mean_spec/G2V.300G.627321.1.lte.' + mu[i] + '.npz')['I'] * 1e+7
    I3_nlt_mean[i, :] = np.load('./mean_spec/G2V.300G.627321.1.nlte.' + mu[i] + '.npz')['I'] * 1e+7
    Is_lte_mean[i, :] = np.load('./mean_spec/G2V.ssd.222809.1.lte.' + mu[i] + '.npz')['I'] * 1e+7
    Is_nlt_mean[i, :] = np.load('./mean_spec/G2V.ssd.222809.1.nlte.' + mu[i] + '.npz')['I'] * 1e+7

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

plt.rcParams.update({'font.size': 6})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

#for 95 - 96
#xmin0 = 2.5; xmax0 = 25
#xmin1 = 2.0; xmax1 = 25
#xmin2 = 2.0; xmax2 = 15
#xmin3 = 1.5; xmax3 = 10
#xmin4 = 1.0; xmax4 = 5

#for 89
#xmin0 = 7.5; xmax0 = 50
#xmin1 = 7.5; xmax1 = 40
#xmin2 = 6.0; xmax2 = 30
#xmin3 = 4.0; xmax3 = 18
#xmin4 = 2.5; xmax4 = 8

#for 20
#xmin0 = 0.000; xmax0 = 1
#xmin1 = 0.000; xmax1 = 0.6
#xmin2 = 0.000; xmax2 = 0.4
#xmin3 = 0.000; xmax3 = 0.2
#xmin4 = 0.000; xmax4 = 0.125

#for 1, 2, 3, 4, 5
#xmin0 = 0.001; xmax0 = 0.2
#xmin1 = 0.001; xmax1 = 0.1
#xmin2 = 0.001; xmax2 = 0.08
#xmin3 = 0.001; xmax3 = 0.05
#xmin4 = 0.001; xmax4 = 0.025

#for 14
#xmin0 = 0.00; xmax0 = 0.1
#xmin1 = 0.00; xmax1 = 0.06
#xmin2 = 0.00; xmax2 = 0.04
#xmin3 = 0.00; xmax3 = 0.03
#xmin4 = 0.00; xmax4 = 0.01

#for 28 - 31
#xmin0 = 0.00; xmax0 = 3.2
#xmin1 = 0.00; xmax1 = 2.8
#xmin2 = 0.00; xmax2 = 2.6
#xmin3 = 0.00; xmax3 = 2.4
#xmin4 = 0.00; xmax4 = 2.2

#for 68 - 74
#xmin0 = 0; xmax0 = 10
#xmin1 = 0; xmax1 = 10
#xmin2 = 0; xmax2 = 10
#xmin3 = 0; xmax3 = 10
#xmin4 = 0; xmax4 = 10

#for 55
xmin0 = 0; xmax0 = 6
xmin1 = 0; xmax1 = 4
xmin2 = 0; xmax2 = 3
xmin3 = 0; xmax3 = 2
xmin4 = 0; xmax4 = 1

#for j in range(94, 96):
#for j in range(88, 89):
#for j in range(19, 20):
#for j in range(0, 5):
#for j in range(13, 14):
#for j in range(27, 31):
#for j in range(67, 74):
for j in range(54, 55):
    
    plt.close('all')

    fig = plt.figure(dpi = 300)

    fig.set_size_inches(6.00, 10.00, forward = True)

    gs = gridspec.GridSpec(7, 2, height_ratios = [1, 0.015, 1, 1, 1, 1, 1])

    spec = plt.subplot(gs[0, :])
    
    plt.subplots_adjust(wspace = 0.12, hspace = 0.3)
    
    spec.plot(w, Is_lte_mean[0, :], linewidth = 0.5, color = 'k')
    
    spec.set_xlabel('Wavelength, nm')
    spec.set_ylabel('Intensity, cgs')
    
    spec.xaxis.set_minor_locator(AutoMinorLocator(10))
    spec.xaxis.set_major_locator(MultipleLocator(10))
    
    spec.axvline(x = w[j], linewidth = 0.5, linestyle = '--')
    
    spec.set_xlim(180, 300)
    
    spec.set_yscale('log')
    
    spec.set_title('#' + str(j + 1))
    
    for i in range(1, 6):
        
        ssd = plt.subplot(gs[i + 1, 0])
        mag = plt.subplot(gs[i + 1, 1])
        
        ssd.set_ylabel(r'Density = $N / N_\mathrm{tot} / \Delta$, $\mu = $' + mu[i - 1])

        mag.yaxis.set_ticklabels([])
    
        ssd.hist(Is_lte[i - 1, :, j], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'LTE')
        ssd.hist(Is_nlt[i - 1, :, j], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'NLTE')
        
        mag.hist(I3_lte[i - 1, :, j], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
        mag.hist(I3_nlt[i - 1, :, j], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
        
        if i == 1: ssd.set_xlim(xmin0, xmax0)
        if i == 2: ssd.set_xlim(xmin1, xmax1)
        if i == 3: ssd.set_xlim(xmin2, xmax2)
        if i == 4: ssd.set_xlim(xmin3, xmax3)
        if i == 5: ssd.set_xlim(xmin4, xmax4)
        
        mag.set_xlim(ssd.get_xlim())
        mag.set_ylim(ssd.get_ylim())
        
        if i == 1:

            ssd.set_title('SSD')
            mag.set_title('300G')
            
            leg = ssd.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})
        
        if i == 5:

            ssd.set_xlabel(r'Intensity, cgs * 10${^7}$')
            mag.set_xlabel(r'Intensity, cgs * 10${^7}$')

    plt.savefig('./fig/hist_plus_spec/' + str(j + 1) + '.pdf', bbox_inches = 'tight')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

#xmin1 = np.zeros(5)
#xmin2 = np.zeros(5)
#xmin3 = np.zeros(5)
#xmin4 = np.zeros(5)
#xmin5 = np.zeros(5)
#xmin6 = np.zeros(5)
#xmin7 = np.zeros(5)
#xmin8 = np.zeros(5)

#xmin1[:] = 0.0
#xmin2[:] = 0.0
#xmin3[:] = 0.0
#xmin4[:] = 0.0
#xmin5[:] = 0.0
#xmin6[:] = 0.0
#xmin7[:] = 0.0
#xmin8[:] = 0.0

xmax1 = [0.1, 0.06, 0.04, 0.03, 0.01]
xmax2 = [1.0, 0.6, 0.4, 0.2, 0.12]
xmax3 = [1.0, 1.0, 0.5, 0.5, 0.25]
xmax4 = [6.0, 4.5, 2.5, 1.0, 0.5]
xmax5 = [15, 10, 6, 3, 2]
xmax6 = [4, 4, 2, 2, 1]
xmax7 = [15, 7, 5, 3, 2]
xmax8 = [20, 15, 7, 4, 3.0]

ymax4 = [0.4, 0.6, 1.0, 2.5, 10.0]
ymax5 = [0.25, 0.4, 0.6, 1.0, 2.5]
ymax6 = [0.8, 1.0, 1.5, 2.0, 3.0]
ymax7 = [0.3, 0.5, 0.75, 1.2, 3.0]
ymax8 = [0.2, 0.3, 0.5, 1.0, 2.0]

j1 = 13
j2 = 19
j3 = 27
j4 = 30
j5 = 67
j6 = 68
j7 = 69
j8 = 70

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 12.5, forward = True)

gs = gridspec.GridSpec(7, 8, height_ratios = [1, 0.015, 1, 1, 1, 1, 1])

spec = plt.subplot(gs[0, :])
    
plt.subplots_adjust(wspace = 0.35, hspace = 0.3)
    
spec.plot(w, Is_lte_mean[4, :], linewidth = 0.5, color = 'k',      label = 'SSD LTE')
spec.plot(w, Is_nlt_mean[4, :], linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
spec.plot(w, I3_lte_mean[4, :], linewidth = 0.5, color = 'b',      label = '300G LTE')
spec.plot(w, I3_nlt_mean[4, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

spec.set_xlabel('Wavelength, nm')
spec.set_ylabel('Intensity, cgs')
    
spec.xaxis.set_minor_locator(AutoMinorLocator(10))
spec.xaxis.set_major_locator(MultipleLocator(10))
    
spec.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j6], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j7], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j8], linewidth = 0.5, linestyle = '--', color = 'k')
    
spec.set_xlim(190, 253)
    
spec.set_yscale('log')

leg = spec.legend(framealpha = 1, loc = 2, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.6, 0.6))

for obj in leg.legendHandles: obj.set_linewidth(2.5)
    
for i in range(1, 6):
        
    w1 = plt.subplot(gs[i + 1, 0])
    w2 = plt.subplot(gs[i + 1, 1])
    w3 = plt.subplot(gs[i + 1, 2])
    w4 = plt.subplot(gs[i + 1, 3])
    w5 = plt.subplot(gs[i + 1, 4])
    w6 = plt.subplot(gs[i + 1, 5])
    w7 = plt.subplot(gs[i + 1, 6])
    w8 = plt.subplot(gs[i + 1, 7])
        
    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$, $\mu = $' + mu[i - 1])

#    w2.yaxis.set_ticklabels([])
#    w3.yaxis.set_ticklabels([])
#    w4.yaxis.set_ticklabels([])
#    w5.yaxis.set_ticklabels([])
#    w6.yaxis.set_ticklabels([])
#    w7.yaxis.set_ticklabels([])
#    w8.yaxis.set_ticklabels([])
    
    w1.hist(Is_lte[i - 1, :, j1], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i - 1, :, j1], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i - 1, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i - 1, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i - 1, :, j2], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i - 1, :, j2], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i - 1, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i - 1, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i - 1, :, j3], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i - 1, :, j3], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i - 1, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i - 1, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i - 1, :, j4], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i - 1, :, j4], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i - 1, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i - 1, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i - 1, :, j5], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i - 1, :, j5], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i - 1, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i - 1, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w6.hist(Is_lte[i - 1, :, j6], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w6.hist(Is_nlt[i - 1, :, j6], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w6.hist(I3_lte[i - 1, :, j6], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w6.hist(I3_nlt[i - 1, :, j6], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w7.hist(Is_lte[i - 1, :, j7], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w7.hist(Is_nlt[i - 1, :, j7], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w7.hist(I3_lte[i - 1, :, j7], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w7.hist(I3_nlt[i - 1, :, j7], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w8.hist(Is_lte[i - 1, :, j8], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w8.hist(Is_nlt[i - 1, :, j8], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w8.hist(I3_lte[i - 1, :, j8], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w8.hist(I3_nlt[i - 1, :, j8], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(0.0, xmax1[i - 1])
    w2.set_xlim(0.0, xmax2[i - 1])
    w3.set_xlim(0.0, xmax3[i - 1])
    w4.set_xlim(0.0, xmax4[i - 1])
    w5.set_xlim(0.0, xmax5[i - 1])
    w6.set_xlim(0.0, xmax6[i - 1])
    w7.set_xlim(0.0, xmax7[i - 1])
    w8.set_xlim(0.0, xmax8[i - 1])
    
    w4.set_ylim(0.0, ymax4[i - 1])
    w5.set_ylim(0.0, ymax5[i - 1])
    w6.set_ylim(0.0, ymax6[i - 1])
    w7.set_ylim(0.0, ymax7[i - 1])
    w8.set_ylim(0.0, ymax8[i - 1])

    if i == 1:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
        w5.set_title(str(w[j5]) + ' nm')
        w6.set_title(str(w[j6]) + ' nm')
        w7.set_title(str(w[j7]) + ' nm')
        w8.set_title(str(w[j8]) + ' nm')
            
#        leg = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})
        
    if i == 5:

        w1.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w2.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w3.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w4.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w5.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w6.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w7.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w8.set_xlabel(r'Intensity, cgs * 10${^7}$')

plt.savefig('./fig/hist_for_paper.pdf', bbox_inches = 'tight')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

#xmin1 = np.zeros(5)
#xmin2 = np.zeros(5)
#xmin3 = np.zeros(5)
#xmin4 = np.zeros(5)
#xmin5 = np.zeros(5)
#xmin6 = np.zeros(5)
#xmin7 = np.zeros(5)
#xmin8 = np.zeros(5)

#xmin1[:] = 0.0
#xmin2[:] = 0.0
#xmin3[:] = 0.0
#xmin4[:] = 0.0
#xmin5[:] = 0.0
#xmin6[:] = 0.0
#xmin7[:] = 0.0
#xmin8[:] = 0.0

xmax1 = [0.1, 0.06, 0.04, 0.03, 0.01]
xmax2 = [1.0, 0.6, 0.4, 0.2, 0.12]
xmax3 = [1.0, 1.0, 0.5, 0.5, 0.25]
xmax4 = [6.0, 4.5, 2.5, 1.0, 0.5]

ymax4 = [0.4, 0.6, 1.0, 2.5, 10.0]

j1 = 13
j2 = 19
j3 = 27
j4 = 30
j5 = 67
j6 = 68
j7 = 69
j8 = 70

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 12.5, forward = True)

gs = gridspec.GridSpec(7, 4, height_ratios = [1, 0.015, 1, 1, 1, 1, 1])

spec = plt.subplot(gs[0, :])
    
plt.subplots_adjust(wspace = 0.15, hspace = 0.3)
    
spec.plot(w, Is_lte_mean[4, :], linewidth = 0.5, color = 'k',      label = 'SSD LTE')
spec.plot(w, Is_nlt_mean[4, :], linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
spec.plot(w, I3_lte_mean[4, :], linewidth = 0.5, color = 'b',      label = '300G LTE')
spec.plot(w, I3_nlt_mean[4, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

spec.set_xlabel('Wavelength, nm')
spec.set_ylabel('Intensity, cgs')
    
spec.xaxis.set_minor_locator(AutoMinorLocator(10))
spec.xaxis.set_major_locator(MultipleLocator(10))
    
spec.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j6], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j7], linewidth = 0.5, linestyle = '--', color = 'k')
spec.axvline(x = w[j8], linewidth = 0.5, linestyle = '--', color = 'k')

spec.set_xlim(190, 253)
    
spec.set_yscale('log')

leg = spec.legend(framealpha = 1, loc = 2, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.6, 0.6))

for obj in leg.legendHandles: obj.set_linewidth(2.5)
    
for i in range(1, 6):
        
    w1 = plt.subplot(gs[i + 1, 0])
    w2 = plt.subplot(gs[i + 1, 1])
    w3 = plt.subplot(gs[i + 1, 2])
    w4 = plt.subplot(gs[i + 1, 3])
        
    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$, $\mu = $' + mu[i - 1])

#    w2.yaxis.set_ticklabels([])
#    w3.yaxis.set_ticklabels([])
#    w4.yaxis.set_ticklabels([])
#    w5.yaxis.set_ticklabels([])
#    w6.yaxis.set_ticklabels([])
#    w7.yaxis.set_ticklabels([])
#    w8.yaxis.set_ticklabels([])
    
    w1.hist(Is_lte[i - 1, :, j1], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i - 1, :, j1], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i - 1, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i - 1, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i - 1, :, j2], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i - 1, :, j2], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i - 1, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i - 1, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i - 1, :, j3], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i - 1, :, j3], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i - 1, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i - 1, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i - 1, :, j4], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i - 1, :, j4], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i - 1, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i - 1, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(0.0, xmax1[i - 1])
    w2.set_xlim(0.0, xmax2[i - 1])
    w3.set_xlim(0.0, xmax3[i - 1])
    w4.set_xlim(0.0, xmax4[i - 1])
    
    w4.set_ylim(0.0, ymax4[i - 1])

    if i == 1:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
            
#        leg = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})
        
    if i == 5:

        w1.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w2.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w3.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w4.set_xlabel(r'Intensity, cgs * 10${^7}$')

plt.savefig('./fig/hist_1.pdf', bbox_inches = 'tight')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

#xmin1 = np.zeros(5)
#xmin2 = np.zeros(5)
#xmin3 = np.zeros(5)
#xmin4 = np.zeros(5)
#xmin5 = np.zeros(5)
#xmin6 = np.zeros(5)
#xmin7 = np.zeros(5)
#xmin8 = np.zeros(5)

#xmin1[:] = 0.0
#xmin2[:] = 0.0
#xmin3[:] = 0.0
#xmin4[:] = 0.0
#xmin5[:] = 0.0
#xmin6[:] = 0.0
#xmin7[:] = 0.0
#xmin8[:] = 0.0

xmax5 = [15, 10, 6, 3, 2]
xmax6 = [4, 4, 2, 2, 1]
xmax7 = [15, 7, 5, 3, 2]
xmax8 = [20, 15, 7, 4, 3.0]

ymax5 = [0.25, 0.4, 0.6, 1.0, 2.5]
ymax6 = [0.8, 1.0, 1.5, 2.0, 3.0]
ymax7 = [0.3, 0.5, 0.75, 1.2, 3.0]
ymax8 = [0.2, 0.3, 0.5, 1.0, 2.0]

j5 = 67
j6 = 68
j7 = 69
j8 = 70

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 10.3, forward = True)

gs = gridspec.GridSpec(5, 4, height_ratios = [1, 1, 1, 1, 1])

#spec = plt.subplot(gs[0, :])
    
plt.subplots_adjust(wspace = 0.15, hspace = 0.3)
    
#spec.plot(w, Is_lte_mean[4, :], linewidth = 0.5, color = 'k',      label = 'SSD LTE')
#spec.plot(w, Is_nlt_mean[4, :], linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
#spec.plot(w, I3_lte_mean[4, :], linewidth = 0.5, color = 'b',      label = '300G LTE')
#spec.plot(w, I3_nlt_mean[4, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

#spec.set_xlabel('Wavelength, nm')
#spec.set_ylabel('Intensity, cgs')
    
#spec.xaxis.set_minor_locator(AutoMinorLocator(10))
#spec.xaxis.set_major_locator(MultipleLocator(10))
    
#spec.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j6], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j7], linewidth = 0.5, linestyle = '--', color = 'k')
#spec.axvline(x = w[j8], linewidth = 0.5, linestyle = '--', color = 'k')
    
#spec.set_xlim(190, 253)
    
#spec.set_yscale('log')

#leg = spec.legend(framealpha = 1, loc = 2, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.6, 0.6))

#for obj in leg.legendHandles: obj.set_linewidth(2.5)
    
for i in range(0, 5):
        
#    w1 = plt.subplot(gs[i + 1, 0])
#    w2 = plt.subplot(gs[i + 1, 1])
#    w3 = plt.subplot(gs[i + 1, 2])
#    w4 = plt.subplot(gs[i + 1, 3])
    w5 = plt.subplot(gs[i, 0])
    w6 = plt.subplot(gs[i, 1])
    w7 = plt.subplot(gs[i, 2])
    w8 = plt.subplot(gs[i, 3])
        
    w5.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$, $\mu = $' + mu[i - 1])

#    w2.yaxis.set_ticklabels([])
#    w3.yaxis.set_ticklabels([])
#    w4.yaxis.set_ticklabels([])
#    w5.yaxis.set_ticklabels([])
#    w6.yaxis.set_ticklabels([])
#    w7.yaxis.set_ticklabels([])
#    w8.yaxis.set_ticklabels([])
    
    w5.hist(Is_lte[i, :, j5], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w6.hist(Is_lte[i, :, j6], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w6.hist(Is_nlt[i, :, j6], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w6.hist(I3_lte[i, :, j6], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w6.hist(I3_nlt[i, :, j6], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w7.hist(Is_lte[i, :, j7], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w7.hist(Is_nlt[i, :, j7], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w7.hist(I3_lte[i, :, j7], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w7.hist(I3_nlt[i, :, j7], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w8.hist(Is_lte[i, :, j8], color = 'k', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w8.hist(Is_nlt[i, :, j8], color = 'r', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w8.hist(I3_lte[i, :, j8], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w8.hist(I3_nlt[i, :, j8], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.set_xlim(0.0, xmax5[i])
    w6.set_xlim(0.0, xmax6[i])
    w7.set_xlim(0.0, xmax7[i])
    w8.set_xlim(0.0, xmax8[i])
    
    w5.set_ylim(0.0, ymax5[i])
    w6.set_ylim(0.0, ymax6[i])
    w7.set_ylim(0.0, ymax7[i])
    w8.set_ylim(0.0, ymax8[i])

    if i == 0:

        w5.set_title(str(w[j5]) + ' nm')
        w6.set_title(str(w[j6]) + ' nm')
        w7.set_title(str(w[j7]) + ' nm')
        w8.set_title(str(w[j8]) + ' nm')
            
#        leg = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})
        
    if i == 4:

        w5.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w6.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w7.set_xlabel(r'Intensity, cgs * 10${^7}$')
        w8.set_xlabel(r'Intensity, cgs * 10${^7}$')

plt.savefig('./fig/hist_2.pdf', bbox_inches = 'tight')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.zeros(3)
xmin2 = np.zeros(3)
xmin3 = np.zeros(3)
xmin4 = np.zeros(3)
xmin5 = np.zeros(3)

xmin1[:] = 0.0
xmin2[:] = 0.0
xmin3 = [0.5, 0.5, 0.2]
xmin4 = [2, 2, 1]
xmin5 = [2.5, 3.0, 1.5]

xmax1 = [0.1, 0.06, 0.04]
xmax2 = [0.04, 0.04, 0.01]
xmax3 = [10.0, 5.0, 1.0]
xmax4 = [20.0, 10.0, 3.0]
xmax5 = [50, 25, 7.5]

ymax4 = [0.4, 0.6, 1.0]

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 7.5, forward = True)

gs = gridspec.GridSpec(5, 5, height_ratios = [1, 0.15, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.225, hspace = 0.3)

spec_xmin = 185
spec_xmax = 270

spec1 = plt.subplot(gs[0, 0])
spec2 = plt.subplot(gs[0, 1])
spec3 = plt.subplot(gs[0, 2])
spec4 = plt.subplot(gs[0, 3])

spec1.plot(w, Is_lte_mean[4, :] * 1e+7, linewidth = 0.5, color = 'k', label = 'SSD LTE')
spec1.plot(w, Is_nlt_mean[4, :] * 1e+7, linewidth = 0.5, color = 'r', label = 'SSD NLTE')

spec2.plot(w, I3_lte_mean[4, :] * 1e+7, linewidth = 0.5, color = 'blue',   label = '300G LTE')
spec2.plot(w, I3_nlt_mean[4, :] * 1e+7, linewidth = 0.5, color = 'orange', label = '300G NLTE')

spec3.plot(w, Is_lte_mean[4, :] * 1e+7, linewidth = 0.5, color = 'k',    label = 'SSD LTE')
spec3.plot(w, I3_lte_mean[4, :] * 1e+7, linewidth = 0.5, color = 'blue', label = '300G LTE')

spec4.plot(w, Is_nlt_mean[4, :] * 1e+7, linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
spec4.plot(w, I3_nlt_mean[4, :] * 1e+7, linewidth = 0.5, color = 'orange', label = '300G NLTE')

spec1.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec1.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec1.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec1.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec1.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

spec2.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec2.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec2.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec2.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec2.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

spec3.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec3.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec3.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec3.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec3.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

spec4.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
spec4.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
spec4.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
spec4.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
spec4.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

spec1.xaxis.set_minor_locator(AutoMinorLocator(5))
spec2.xaxis.set_minor_locator(AutoMinorLocator(5))
spec3.xaxis.set_minor_locator(AutoMinorLocator(5))
spec4.xaxis.set_minor_locator(AutoMinorLocator(5))

leg1 = spec1.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
leg2 = spec2.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
leg3 = spec3.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
leg4 = spec4.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})

for obj in leg1.legendHandles: obj.set_linewidth(2.5)
for obj in leg2.legendHandles: obj.set_linewidth(2.5)
for obj in leg3.legendHandles: obj.set_linewidth(2.5)
for obj in leg4.legendHandles: obj.set_linewidth(2.5)

spec1.set_xlim(spec_xmin, spec_xmax)
spec2.set_xlim(spec_xmin, spec_xmax)
spec3.set_xlim(spec_xmin, spec_xmax)
spec4.set_xlim(spec_xmin, spec_xmax)

spec1.set_yscale('log')
spec2.set_yscale('log')
spec3.set_yscale('log')
spec4.set_yscale('log')

spec1.set_ylabel(r'Intensity, cgs $\times$ 10${^7}$')

spec4.set_ylabel(r'$\mu =$1.0')
spec4.yaxis.set_label_position("right")

spec1.set_xlabel(r'Wavelength, nm')
spec2.set_xlabel(r'Wavelength, nm')
spec3.set_xlabel(r'Wavelength, nm')
spec4.set_xlabel(r'Wavelength, nm')
    
for k, i in enumerate(idx_mu):
        
    w1 = plt.subplot(gs[k + 2, 0])
    w2 = plt.subplot(gs[k + 2, 1])
    w3 = plt.subplot(gs[k + 2, 2])
    w4 = plt.subplot(gs[k + 2, 3])
    w5 = plt.subplot(gs[k + 2, 4])

    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w5.set_ylabel(r'$\mu =$' + mu[i])
    w5.yaxis.set_label_position("right")

    if i == 0:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
        w5.set_title(str(w[j5]) + ' nm')

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)

    if i == 4:

        w1.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w2.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w3.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w4.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')

plt.savefig('./fig/intensity_hist_one_panel_for_spec.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.zeros(3)
xmin2 = np.zeros(3)
xmin3 = np.zeros(3)
xmin4 = np.zeros(3)
xmin5 = np.zeros(3)

xmin1[:] = 0.0
xmin2[:] = 0.0
xmin3 = [0.5, 0.5, 0.2]
xmin4 = [2, 2, 1]
xmin5 = [2.5, 3.0, 1.5]

xmax1 = [0.1, 0.06, 0.04]
xmax2 = [0.04, 0.04, 0.01]
xmax3 = [10.0, 5.0, 1.0]
xmax4 = [20.0, 10.0, 3.0]
xmax5 = [50, 25, 7.5]

#ymax4 = [0.4, 0.6, 1.0]

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 11.25, forward = True)

gs = gridspec.GridSpec(7, 5, height_ratios = [1, 1, 1, 0.15, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.325, hspace = 0.3)

spec_xmin = 185
spec_xmax = 270
    
for k, i in enumerate(idx_mu):
    
    spec1 = plt.subplot(gs[k, 0])
    spec2 = plt.subplot(gs[k, 1])
    spec3 = plt.subplot(gs[k, 2])
    spec4 = plt.subplot(gs[k, 3])
    
    spec1.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec2.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec3.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec4.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec1.plot(w, Is_lte_mean[4 - i, :], linewidth = 0.5, color = 'k', label = 'SSD LTE')
    spec1.plot(w, Is_nlt_mean[4 - i, :], linewidth = 0.5, color = 'r', label = 'SSD NLTE')

    spec2.plot(w, I3_lte_mean[4 - i, :], linewidth = 0.5, color = 'blue',   label = '300G LTE')
    spec2.plot(w, I3_nlt_mean[4 - i, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec3.plot(w, Is_lte_mean[4 - i, :], linewidth = 0.5, color = 'k',    label = 'SSD LTE')
    spec3.plot(w, I3_lte_mean[4 - i, :], linewidth = 0.5, color = 'blue', label = '300G LTE')

    spec4.plot(w, Is_nlt_mean[4 - i, :], linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
    spec4.plot(w, I3_nlt_mean[4 - i, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec1.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec2.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec3.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec4.xaxis.set_minor_locator(AutoMinorLocator(5))

    spec1.set_xlim(spec_xmin, spec_xmax)
    spec2.set_xlim(spec_xmin, spec_xmax)
    spec3.set_xlim(spec_xmin, spec_xmax)
    spec4.set_xlim(spec_xmin, spec_xmax)

    spec1.set_yscale('log')
    spec2.set_yscale('log')
    spec3.set_yscale('log')
    spec4.set_yscale('log')

    spec1.set_ylabel(r'Intensity, cgs $\times$ 10${^7}$')

    spec4.set_ylabel(r'$\mu =$' + mu[i])
    spec4.yaxis.set_label_position("right")
    
    if i == 0:
        
        leg1 = spec1.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg2 = spec2.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg3 = spec3.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg4 = spec4.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
        for obj in leg2.legendHandles: obj.set_linewidth(2.5)
        for obj in leg3.legendHandles: obj.set_linewidth(2.5)
        for obj in leg4.legendHandles: obj.set_linewidth(2.5)
    
    if i == 4:

        spec1.set_xlabel(r'Wavelength, nm')
        spec2.set_xlabel(r'Wavelength, nm')
        spec3.set_xlabel(r'Wavelength, nm')
        spec4.set_xlabel(r'Wavelength, nm')
        
    w1 = plt.subplot(gs[k + 4, 0])
    w2 = plt.subplot(gs[k + 4, 1])
    w3 = plt.subplot(gs[k + 4, 2])
    w4 = plt.subplot(gs[k + 4, 3])
    w5 = plt.subplot(gs[k + 4, 4])

    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w5.set_ylabel(r'$\mu =$' + mu[i])
    w5.yaxis.set_label_position("right")

    if i == 0:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
        w5.set_title(str(w[j5]) + ' nm')

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)

    if i == 4:

        w1.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w2.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w3.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w4.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')

plt.savefig('./fig/intensity_hist_absolute.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.zeros(3)
xmin2 = np.zeros(3)
xmin3 = np.zeros(3)
xmin4 = np.zeros(3)
xmin5 = np.zeros(3)

xmin1[:] = 0.0
xmin2[:] = 0.0
xmin3 = [0.0, 0.0, 0.0]
xmin4 = [0.3, 0.3, 0.3]
xmin5 = [0.3, 0.3, 0.3]

xmax1 = [2, 2, 2]
xmax2 = [2, 2, 2]
xmax3 = [2, 2, 2]
xmax4 = [2, 2, 2]
xmax5 = [2, 2, 2]

#ymax4 = [0.4, 0.6, 1.0]

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 11.25, forward = True)

gs = gridspec.GridSpec(7, 5, height_ratios = [1, 1, 1, 0.15, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.325, hspace = 0.3)

spec_xmin = 185
spec_xmax = 270
    
for k, i in enumerate(idx_mu):
    
    spec1 = plt.subplot(gs[k, 0])
    spec2 = plt.subplot(gs[k, 1])
    spec3 = plt.subplot(gs[k, 2])
    spec4 = plt.subplot(gs[k, 3])
    
    spec1.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec2.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec3.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec4.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec1.plot(w, Is_lte_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'k', label = 'SSD LTE')
    spec1.plot(w, Is_nlt_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'r', label = 'SSD NLTE')

    spec2.plot(w, I3_lte_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'blue',   label = '300G LTE')
    spec2.plot(w, I3_nlt_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec3.plot(w, Is_lte_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'k',    label = 'SSD LTE')
    spec3.plot(w, I3_lte_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'blue', label = '300G LTE')

    spec4.plot(w, Is_nlt_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
    spec4.plot(w, I3_nlt_mean[4 - i, :] / 1e+7, linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec1.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec2.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec3.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec4.xaxis.set_minor_locator(AutoMinorLocator(5))

    spec1.set_xlim(spec_xmin, spec_xmax)
    spec2.set_xlim(spec_xmin, spec_xmax)
    spec3.set_xlim(spec_xmin, spec_xmax)
    spec4.set_xlim(spec_xmin, spec_xmax)

    spec1.set_yscale('log')
    spec2.set_yscale('log')
    spec3.set_yscale('log')
    spec4.set_yscale('log')

    spec1.set_ylabel(r'Intensity, cgs')

    spec4.set_ylabel(r'$\mu =$' + mu[i])
    spec4.yaxis.set_label_position("right")
    
    if i == 0:
        
        leg1 = spec1.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg2 = spec2.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg3 = spec3.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg4 = spec4.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
        for obj in leg2.legendHandles: obj.set_linewidth(2.5)
        for obj in leg3.legendHandles: obj.set_linewidth(2.5)
        for obj in leg4.legendHandles: obj.set_linewidth(2.5)
    
    if i == 4:

        spec1.set_xlabel(r'Wavelength, nm')
        spec2.set_xlabel(r'Wavelength, nm')
        spec3.set_xlabel(r'Wavelength, nm')
        spec4.set_xlabel(r'Wavelength, nm')
        
    w1 = plt.subplot(gs[k + 4, 0])
    w2 = plt.subplot(gs[k + 4, 1])
    w3 = plt.subplot(gs[k + 4, 2])
    w4 = plt.subplot(gs[k + 4, 3])
    w5 = plt.subplot(gs[k + 4, 4])

    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    w1.hist(Is_lte[i, :, j1] / Is_lte_mean[4 - i, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1] / Is_nlt_mean[4 - i, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1] / I3_lte_mean[4 - i, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1] / I3_nlt_mean[4 - i, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i, :, j2] / Is_lte_mean[4 - i, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2] / Is_nlt_mean[4 - i, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2] / I3_lte_mean[4 - i, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2] / I3_nlt_mean[4 - i, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i, :, j3] / Is_lte_mean[4 - i, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3] / Is_nlt_mean[4 - i, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3] / I3_lte_mean[4 - i, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3] / I3_nlt_mean[4 - i, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i, :, j4] / Is_lte_mean[4 - i, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4] / Is_nlt_mean[4 - i, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4] / I3_lte_mean[4 - i, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4] / I3_nlt_mean[4 - i, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i, :, j5] / Is_lte_mean[4 - i, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5] / Is_nlt_mean[4 - i, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5] / I3_lte_mean[4 - i, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5] / I3_nlt_mean[4 - i, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w5.set_ylabel(r'$\mu =$' + mu[i])
    w5.yaxis.set_label_position("right")

    if i == 0:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
        w5.set_title(str(w[j5]) + ' nm')

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)

    if i == 4:

        w1.set_xlabel(r'$I / I_\mathrm{mean}$')
        w2.set_xlabel(r'$I / I_\mathrm{mean}$')
        w3.set_xlabel(r'$I / I_\mathrm{mean}$')
        w4.set_xlabel(r'$I / I_\mathrm{mean}$')
        w5.set_xlabel(r'$I / I_\mathrm{mean}$')

plt.savefig('./fig/intensity_hist_div_by_mean.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.zeros(3)
xmin2 = np.zeros(3)
xmin3 = np.zeros(3)
xmin4 = np.zeros(3)
xmin5 = np.zeros(3)

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(15, 16.875, forward = True)

gs = gridspec.GridSpec(11, 5, height_ratios = [1, 1, 1, 0.15, 1, 1, 1, 0.01, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.325, hspace = 0.3)

spec_xmin = 185
spec_xmax = 270
    
for k, i in enumerate(idx_mu):
    
    spec1 = plt.subplot(gs[k, 0])
    spec2 = plt.subplot(gs[k, 1])
    spec3 = plt.subplot(gs[k, 2])
    spec4 = plt.subplot(gs[k, 3])
    
    spec1.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec1.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec2.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec2.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec3.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec3.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec4.axvline(x = w[j1], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j2], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j3], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j4], linewidth = 0.5, linestyle = '--', color = 'k')
    spec4.axvline(x = w[j5], linewidth = 0.5, linestyle = '--', color = 'k')

    spec1.plot(w, Is_lte_mean[4 - i, :], linewidth = 0.5, color = 'k', label = 'SSD LTE')
    spec1.plot(w, Is_nlt_mean[4 - i, :], linewidth = 0.5, color = 'r', label = 'SSD NLTE')

    spec2.plot(w, I3_lte_mean[4 - i, :], linewidth = 0.5, color = 'blue',   label = '300G LTE')
    spec2.plot(w, I3_nlt_mean[4 - i, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec3.plot(w, Is_lte_mean[4 - i, :], linewidth = 0.5, color = 'k',    label = 'SSD LTE')
    spec3.plot(w, I3_lte_mean[4 - i, :], linewidth = 0.5, color = 'blue', label = '300G LTE')

    spec4.plot(w, Is_nlt_mean[4 - i, :], linewidth = 0.5, color = 'r',      label = 'SSD NLTE')
    spec4.plot(w, I3_nlt_mean[4 - i, :], linewidth = 0.5, color = 'orange', label = '300G NLTE')

    spec1.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec2.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec3.xaxis.set_minor_locator(AutoMinorLocator(5))
    spec4.xaxis.set_minor_locator(AutoMinorLocator(5))

    spec1.set_xlim(spec_xmin, spec_xmax)
    spec2.set_xlim(spec_xmin, spec_xmax)
    spec3.set_xlim(spec_xmin, spec_xmax)
    spec4.set_xlim(spec_xmin, spec_xmax)

    spec1.set_yscale('log')
    spec2.set_yscale('log')
    spec3.set_yscale('log')
    spec4.set_yscale('log')

    spec1.set_ylabel(r'Intensity, cgs $\times$ 10${^7}$')

    spec4.set_ylabel(r'$\mu =$' + mu[i])
    spec4.yaxis.set_label_position("right")
    
    if i == 0:
        
        leg1 = spec1.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg2 = spec2.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg3 = spec3.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})
        leg4 = spec4.legend(framealpha = 1, loc = 4, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
        for obj in leg2.legendHandles: obj.set_linewidth(2.5)
        for obj in leg3.legendHandles: obj.set_linewidth(2.5)
        for obj in leg4.legendHandles: obj.set_linewidth(2.5)
    
    if i == 4:

        spec1.set_xlabel(r'Wavelength, nm')
        spec2.set_xlabel(r'Wavelength, nm')
        spec3.set_xlabel(r'Wavelength, nm')
        spec4.set_xlabel(r'Wavelength, nm')
        
    xmin1[:] = 0.0
    xmin2[:] = 0.0
    xmin3 = [0.5, 0.5, 0.2]
    xmin4 = [2, 2, 1]
    xmin5 = [2.5, 3.0, 1.5]

    xmax1 = [0.1, 0.06, 0.04]
    xmax2 = [0.04, 0.04, 0.01]
    xmax3 = [10.0, 5.0, 1.0]
    xmax4 = [20.0, 10.0, 3.0]
    xmax5 = [50, 25, 7.5]
        
    w1 = plt.subplot(gs[k + 4, 0])
    w2 = plt.subplot(gs[k + 4, 1])
    w3 = plt.subplot(gs[k + 4, 2])
    w4 = plt.subplot(gs[k + 4, 3])
    w5 = plt.subplot(gs[k + 4, 4])

    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w5.set_ylabel(r'$\mu =$' + mu[i])
    w5.yaxis.set_label_position("right")

    if i == 0:

        w1.set_title(str(w[j1]) + ' nm')
        w2.set_title(str(w[j2]) + ' nm')
        w3.set_title(str(w[j3]) + ' nm')
        w4.set_title(str(w[j4]) + ' nm')
        w5.set_title(str(w[j5]) + ' nm')

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)

    if i == 4:

        w1.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w2.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w3.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w4.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
        
    xmin1[:] = 0.0
    xmin2[:] = 0.0
    xmin3 = [0.0, 0.0, 0.0]
    xmin4 = [0.3, 0.3, 0.3]
    xmin5 = [0.3, 0.3, 0.3]

    xmax1 = [2, 2, 2]
    xmax2 = [2, 2, 2]
    xmax3 = [2, 2, 2]
    xmax4 = [2, 2, 2]
    xmax5 = [2, 2, 2]
        
    w1 = plt.subplot(gs[k + 8, 0])
    w2 = plt.subplot(gs[k + 8, 1])
    w3 = plt.subplot(gs[k + 8, 2])
    w4 = plt.subplot(gs[k + 8, 3])
    w5 = plt.subplot(gs[k + 8, 4])

    w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    w1.hist(Is_lte[i, :, j1] / Is_lte_mean[4 - i, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1] / Is_nlt_mean[4 - i, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1] / I3_lte_mean[4 - i, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1] / I3_nlt_mean[4 - i, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
        
    w2.hist(Is_lte[i, :, j2] / Is_lte_mean[4 - i, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2] / Is_nlt_mean[4 - i, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2] / I3_lte_mean[4 - i, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2] / I3_nlt_mean[4 - i, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(Is_lte[i, :, j3] / Is_lte_mean[4 - i, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3] / Is_nlt_mean[4 - i, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3] / I3_lte_mean[4 - i, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3] / I3_nlt_mean[4 - i, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(Is_lte[i, :, j4] / Is_lte_mean[4 - i, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4] / Is_nlt_mean[4 - i, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4] / I3_lte_mean[4 - i, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4] / I3_nlt_mean[4 - i, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(Is_lte[i, :, j5] / Is_lte_mean[4 - i, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5] / Is_nlt_mean[4 - i, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5] / I3_lte_mean[4 - i, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5] / I3_nlt_mean[4 - i, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w5.set_ylabel(r'$\mu =$' + mu[i])
    w5.yaxis.set_label_position("right")

#    if i == 0:
#
#        w1.set_title(str(w[j1]) + ' nm')
#        w2.set_title(str(w[j2]) + ' nm')
#        w3.set_title(str(w[j3]) + ' nm')
#        w4.set_title(str(w[j4]) + ' nm')
#        w5.set_title(str(w[j5]) + ' nm')

#        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5})

#        for obj in leg1.legendHandles: obj.set_linewidth(2.5)

    if i == 4:

        w1.set_xlabel(r'$I / I_\mathrm{average}$')
        w2.set_xlabel(r'$I / I_\mathrm{average}$')
        w3.set_xlabel(r'$I / I_\mathrm{average}$')
        w4.set_xlabel(r'$I / I_\mathrm{average}$')
        w5.set_xlabel(r'$I / I_\mathrm{average}$')

plt.savefig('./fig/intensity_hist.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

def mark_mean(w, i1, i2, pos, col):
    
    ymax = w.get_ylim()[1] / 4
    
    w.plot(np.array([pos, pos]), np.array([i1 * ymax, i2 * ymax]), color = col, linewidth = 1.25)
    
    return

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.zeros(3)
xmin2 = np.zeros(3)
xmin3 = np.zeros(3)
xmin4 = np.zeros(3)
xmin5 = np.zeros(3)

xmin1[:] = 0.0
xmin2[:] = 0.0
xmin3 = [0.0, 0.5, 0.2]
xmin4 = [2, 2, 1]
xmin5 = [2.5, 3.0, 1.5]

xmax1 = [0.40, 0.14, 0.05]
xmax2 = [0.08, 0.05, 0.020]
xmax3 = [25.0, 10.0, 1.1]
xmax4 = [20.0, 10.0, 3.0]
xmax5 = [50, 25, 7.5]

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(12.5, 8.5, forward = True)

gs = gridspec.GridSpec(5, 3, height_ratios = [1, 1, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.200, hspace = 0.3)
    
for k, i in enumerate(idx_mu):

    w1 = plt.subplot(gs[0, k])
    w2 = plt.subplot(gs[1, k])
    w3 = plt.subplot(gs[2, k])
    w4 = plt.subplot(gs[3, k])
    w5 = plt.subplot(gs[4, k])

    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
    
    mark_mean(w1, 0, 1, Is_lte_mean[4 - i, j1], 'k')
    mark_mean(w1, 3, 4, Is_nlt_mean[4 - i, j1], 'r')
    mark_mean(w1, 2, 3, I3_lte_mean[4 - i, j1], 'b')
    mark_mean(w1, 1, 2, I3_nlt_mean[4 - i, j1], 'orange')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w2, 0, 1, Is_lte_mean[4 - i, j2], 'k')
    mark_mean(w2, 3, 4, Is_nlt_mean[4 - i, j2], 'r')
    mark_mean(w2, 2, 3, I3_lte_mean[4 - i, j2], 'b')
    mark_mean(w2, 1, 2, I3_nlt_mean[4 - i, j2], 'orange')
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w3, 1, 2, Is_lte_mean[4 - i, j3], 'k')
    mark_mean(w3, 3, 4, Is_nlt_mean[4 - i, j3], 'r')
    mark_mean(w3, 2, 3, I3_lte_mean[4 - i, j3], 'b')
    mark_mean(w3, 0, 1, I3_nlt_mean[4 - i, j3], 'orange')
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)

    mark_mean(w4, 0, 1, Is_lte_mean[4 - i, j4], 'k')
    mark_mean(w4, 3, 4, Is_nlt_mean[4 - i, j4], 'r')
    mark_mean(w4, 1, 2, I3_lte_mean[4 - i, j4], 'b')
    mark_mean(w4, 2, 3, I3_nlt_mean[4 - i, j4], 'orange')
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w5, 0, 1, Is_lte_mean[4 - i, j5], 'k')
    mark_mean(w5, 3, 4, Is_nlt_mean[4 - i, j5], 'r')
    mark_mean(w5, 1, 2, I3_lte_mean[4 - i, j5], 'b')
    mark_mean(w5, 2, 3, I3_nlt_mean[4 - i, j5], 'orange')
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
        
    w1.set_title(r'$\mu =$' + mu[i])
    w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')
    
    if i == 0:

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.8, 0.97))

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
            
        w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w2.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w3.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w4.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w5.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    if i == 4:

        w1.set_ylabel(str(w[j1]) + ' nm')
        w2.set_ylabel(str(w[j2]) + ' nm')
        w3.set_ylabel(str(w[j3]) + ' nm')
        w4.set_ylabel(str(w[j4]) + ' nm')
        w5.set_ylabel(str(w[j5]) + ' nm')
        
        w1.yaxis.set_label_position("right")
        w2.yaxis.set_label_position("right")
        w3.yaxis.set_label_position("right")
        w4.yaxis.set_label_position("right")
        w5.yaxis.set_label_position("right")

plt.savefig('./fig/intensity_hist.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
def calc_means(mu, a):
    
    a = a[~np.isnan(a)]
    
    up1 = np.percentile(a, 99)
    lp1 = np.percentile(a, 1)
    
    up5 = np.percentile(a, 95)
    lp5 = np.percentile(a, 5)
    
    mean = np.mean(a)
    
    mean_1 = np.mean(a[np.where((a >= lp1) & (a <= up1))])
    
    mean_5 = np.mean(a[np.where((a >= lp5) & (a <= up5))])
    
    median = np.median(a)
    
    print('mu = ', mu.replace(' ', ''), ': mean = ', str(mean)[:5], ' mean_1 = ', str(mean_1)[:5], ' mean_5 = ', str(mean_5)[:5], ' median = ', str(median)[:5]) 
    
    return

print('187.5 nm')
print('===============')
print('Is_lte')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], Is_lte[i, :, j1])
print('===============')
print('Is_nlt')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], Is_nlt[i, :, j1])
print('===============')
print('I3_lte')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], I3_lte[i, :, j1])
print('===============')
print('I3_nlt')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], I3_nlt[i, :, j1])
print('===============')
print('193.5 nm')
print('===============')
print('Is_lte')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], Is_lte[i, :, j2])
print('===============')
print('Is_nlt')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], Is_nlt[i, :, j2])
print('===============')
print('I3_lte')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], I3_lte[i, :, j2])
print('===============')
print('I3_nlt')
print('===============')
for k, i in enumerate(idx_mu): calc_means(mu[i], I3_nlt[i, :, j2])
# Out:
# 187.5 nm
# ...
# Is_lte
# ...
# mu =  1.0 : mean =  0.045  mean_1 =  0.041  mean_5 =  0.038  median =  0.029
# mu =  0.6 : mean =  0.027  mean_1 =  0.026  mean_5 =  0.024  median =  0.018
# mu =  0.2 : mean =  0.010  mean_1 =  0.010  mean_5 =  0.009  median =  0.007
# ...
# Is_nlt
# ...
# mu =  1.0 : mean =  0.333  mean_1 =  0.317  mean_5 =  0.271  median =  0.112
# mu =  0.6 : mean =  0.039  mean_1 =  0.035  mean_5 =  0.032  median =  0.027
# mu =  0.2 : mean =  0.013  mean_1 =  0.012  mean_5 =  0.012  median =  0.011
# ...
# I3_lte
# ...
# mu =  1.0 : mean =  0.119  mean_1 =  0.102  mean_5 =  0.079  median =  0.049
# mu =  0.6 : mean =  0.062  mean_1 =  0.055  mean_5 =  0.048  median =  0.035
# mu =  0.2 : mean =  0.021  mean_1 =  0.021  mean_5 =  0.020  median =  0.018
# ...
# I3_nlt
# ...
# mu =  1.0 : mean =  0.376  mean_1 =  0.354  mean_5 =  0.310  median =  0.156
# mu =  0.6 : mean =  0.120  mean_1 =  0.085  mean_5 =  0.059  median =  0.038
# mu =  0.2 : mean =  0.023  mean_1 =  0.020  mean_5 =  0.019  median =  0.016
# ...

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

def mark_mean(w, i1, i2, pos, col):
    
    ymax = w.get_ylim()[1] / 4
    
    w.plot(np.array([pos, pos]), np.array([i1 * ymax, i2 * ymax]), color = col, linewidth = 1.25)
    
    return

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.array([3e-3, 1e-4, 1e-4])# * 1e-7
xmin2 = np.array([1e-3, 1e-4, 4e-5])# * 1e-7
xmin3 = np.array([5e-1, 0.5, 0.2])#   * 1e-7
xmin4 = np.array([3, 2, 1])#          * 1e-7
xmin5 = np.array([6, 3.0, 1.5])#    * 1e-7

xmax1 = np.array([0.40, 0.14, 0.05])#  * 1e-7
xmax2 = np.array([0.08, 0.05, 0.020])# * 1e-7
xmax3 = np.array([25.0, 10.0, 1.1])#   * 1e-7
xmax4 = np.array([20.0, 10.0, 3.0])#   * 1e-7
xmax5 = np.array([50, 25, 7.5])#      * 1e-7

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(12.5, 8.5, forward = True)

gs = gridspec.GridSpec(5, 3, height_ratios = [1, 1, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.200, hspace = 0.3)
    
for k, i in enumerate(idx_mu):

    w1 = plt.subplot(gs[0, k])
    w2 = plt.subplot(gs[1, k])
    w3 = plt.subplot(gs[2, k])
    w4 = plt.subplot(gs[3, k])
    w5 = plt.subplot(gs[4, k])

    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
    
    mark_mean(w1, 2, 3, Is_lte_mean[4 - i, j1], 'k')
    mark_mean(w1, 3, 4, Is_nlt_mean[4 - i, j1], 'r')
    mark_mean(w1, 0, 1, I3_lte_mean[4 - i, j1], 'b')
    mark_mean(w1, 1, 2, I3_nlt_mean[4 - i, j1], 'orange')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w2, 0, 1, Is_lte_mean[4 - i, j2], 'k')
    mark_mean(w2, 3, 4, Is_nlt_mean[4 - i, j2], 'r')
    mark_mean(w2, 2, 3, I3_lte_mean[4 - i, j2], 'b')
    mark_mean(w2, 1, 2, I3_nlt_mean[4 - i, j2], 'orange')
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w3, 1, 2, Is_lte_mean[4 - i, j3], 'k')
    mark_mean(w3, 3, 4, Is_nlt_mean[4 - i, j3], 'r')
    mark_mean(w3, 2, 3, I3_lte_mean[4 - i, j3], 'b')
    mark_mean(w3, 0, 1, I3_nlt_mean[4 - i, j3], 'orange')
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)

    mark_mean(w4, 0, 1, Is_lte_mean[4 - i, j4], 'k')
    mark_mean(w4, 3, 4, Is_nlt_mean[4 - i, j4], 'r')
    mark_mean(w4, 1, 2, I3_lte_mean[4 - i, j4], 'b')
    mark_mean(w4, 2, 3, I3_nlt_mean[4 - i, j4], 'orange')
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w5, 0, 1, Is_lte_mean[4 - i, j5], 'k')
    mark_mean(w5, 3, 4, Is_nlt_mean[4 - i, j5], 'r')
    mark_mean(w5, 1, 2, I3_lte_mean[4 - i, j5], 'b')
    mark_mean(w5, 2, 3, I3_nlt_mean[4 - i, j5], 'orange')
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
        
    w1.set_title(r'$\mu =$' + mu[i])
    w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')

    w1.set_xscale('log')
    w2.set_xscale('log')
    w3.set_xscale('log')
    w4.set_xscale('log')
    w5.set_xscale('log')

    if i == 0:

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.95, 0.97))

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
            
        w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w2.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w3.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w4.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w5.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    if i == 4:

        w1.set_ylabel(str(w[j1]) + ' nm')
        w2.set_ylabel(str(w[j2]) + ' nm')
        w3.set_ylabel(str(w[j3]) + ' nm')
        w4.set_ylabel(str(w[j4]) + ' nm')
        w5.set_ylabel(str(w[j5]) + ' nm')
        
        w1.yaxis.set_label_position("right")
        w2.yaxis.set_label_position("right")
        w3.yaxis.set_label_position("right")
        w4.yaxis.set_label_position("right")
        w5.yaxis.set_label_position("right")

plt.savefig('./fig/intensity_hist_xlog.pdf', bbox_inches = 'tight')

plt.close('all')

# %%
from matplotlib.ticker import AutoMinorLocator
from matplotlib.ticker import MultipleLocator

import matplotlib.pyplot as plt

import os

from tqdm import tqdm

import matplotlib.gridspec as gridspec

def mark_mean(w, i1, i2, pos, col):
    
    ymin = w.get_ylim()[0]
    ymax = w.get_ylim()[1]
    
    dy = (ymax - ymin) / 4
    
    w.plot(np.array([pos, pos]), np.array([ymin + i1 * dy, ymin + i2 * dy]), color = col, linewidth = 1.25)
    
    return

mu = ['1.0', '0.8', '0.6', '0.4', '0.2']

idx_mu = [0, 2, 4]

plt.rcParams.update({'font.size': 10})
plt.rcParams["font.family"] = 'Times New Roman'

nbins = 3000

pdfs = ''

xmin1 = np.array([3e-3, 1e-4, 1e-4]) * 1e-7
xmin2 = np.array([1e-3, 1e-4, 4e-5]) * 1e-7
xmin3 = np.array([5e-1, 0.5, 0.2])   * 1e-7
xmin4 = np.array([3, 2, 1])          * 1e-7
xmin5 = np.array([6, 3.0, 1.5])    * 1e-7

xmax1 = np.array([0.40, 0.14, 0.05])  * 1e-7
xmax2 = np.array([0.08, 0.05, 0.020]) * 1e-7
xmax3 = np.array([25.0, 10.0, 1.1])   * 1e-7
xmax4 = np.array([20.0, 10.0, 3.0])   * 1e-7
xmax5 = np.array([50, 25, 7.5])      * 1e-7

ymin1 = np.array([3e-3, 1e-4, 1e-4])
ymin2 = np.array([1e-3, 1e-4, 4e-5])
ymin3 = np.array([5e-1, 0.5, 0.2])
ymin4 = np.array([1e+3, 1e+3, 1e+5])
ymin5 = np.array([6, 3.0, 1.5])

ymax1 = np.array([0.40, 0.14, 0.05])
ymax2 = np.array([0.08, 0.05, 0.020])
ymax3 = np.array([25.0, 10.0, 1.1])
ymax4 = np.array([1e+6, 1e+6, 1.5e+7])
ymax5 = np.array([50, 25, 7.5])

j1 = 7
j2 = 13
j3 = 50
j4 = 82
j5 = 84

plt.close('all')

fig = plt.figure(dpi = 300)

fig.set_size_inches(12.5, 8.5, forward = True)

gs = gridspec.GridSpec(5, 3, height_ratios = [1, 1, 1, 1, 1])
    
plt.subplots_adjust(wspace = 0.200, hspace = 0.3)
    
for k, i in enumerate(idx_mu):

    w1 = plt.subplot(gs[0, k])
    w2 = plt.subplot(gs[1, k])
    w3 = plt.subplot(gs[2, k])
    w4 = plt.subplot(gs[3, k])
    w5 = plt.subplot(gs[4, k])

    w1.hist(Is_lte[i, :, j1], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD LTE')
    w1.hist(Is_nlt[i, :, j1], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = 'SSD NLTE')

    w1.hist(I3_lte[i, :, j1], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G LTE')
    w1.hist(I3_nlt[i, :, j1], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5, label = '300G NLTE')
    
    mark_mean(w1, 2, 3, Is_lte_mean[4 - i, j1], 'k')
    mark_mean(w1, 3, 4, Is_nlt_mean[4 - i, j1], 'r')
    mark_mean(w1, 0, 1, I3_lte_mean[4 - i, j1], 'b')
    mark_mean(w1, 1, 2, I3_nlt_mean[4 - i, j1], 'orange')
        
    w2.hist(Is_lte[i, :, j2], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(Is_nlt[i, :, j2], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w2.hist(I3_lte[i, :, j2], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w2.hist(I3_nlt[i, :, j2], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w2, 0, 1, Is_lte_mean[4 - i, j2], 'k')
    mark_mean(w2, 3, 4, Is_nlt_mean[4 - i, j2], 'r')
    mark_mean(w2, 2, 3, I3_lte_mean[4 - i, j2], 'b')
    mark_mean(w2, 1, 2, I3_nlt_mean[4 - i, j2], 'orange')
    
    w3.hist(Is_lte[i, :, j3], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(Is_nlt[i, :, j3], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w3.hist(I3_lte[i, :, j3], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w3.hist(I3_nlt[i, :, j3], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w3, 1, 2, Is_lte_mean[4 - i, j3], 'k')
    mark_mean(w3, 3, 4, Is_nlt_mean[4 - i, j3], 'r')
    mark_mean(w3, 2, 3, I3_lte_mean[4 - i, j3], 'b')
    mark_mean(w3, 0, 1, I3_nlt_mean[4 - i, j3], 'orange')
    
    w4.hist(Is_lte[i, :, j4], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(Is_nlt[i, :, j4], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w4.hist(I3_lte[i, :, j4], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w4.hist(I3_nlt[i, :, j4], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)

    mark_mean(w4, 0, 1, Is_lte_mean[4 - i, j4], 'k')
    mark_mean(w4, 3, 4, Is_nlt_mean[4 - i, j4], 'r')
    mark_mean(w4, 1, 2, I3_lte_mean[4 - i, j4], 'b')
    mark_mean(w4, 2, 3, I3_nlt_mean[4 - i, j4], 'orange')
    
    w5.hist(Is_lte[i, :, j5], color = 'k',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(Is_nlt[i, :, j5], color = 'r',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    w5.hist(I3_lte[i, :, j5], color = 'b',      bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    w5.hist(I3_nlt[i, :, j5], color = 'orange', bins = nbins, histtype = 'step', density = True, linewidth = 0.5)
    
    mark_mean(w5, 0, 1, Is_lte_mean[4 - i, j5], 'k')
    mark_mean(w5, 3, 4, Is_nlt_mean[4 - i, j5], 'r')
    mark_mean(w5, 1, 2, I3_lte_mean[4 - i, j5], 'b')
    mark_mean(w5, 2, 3, I3_nlt_mean[4 - i, j5], 'orange')
    
    w1.set_xlim(xmin1[k], xmax1[k])
    w2.set_xlim(xmin2[k], xmax2[k])
    w3.set_xlim(xmin3[k], xmax3[k])
    w4.set_xlim(xmin4[k], xmax4[k])
    w5.set_xlim(xmin5[k], xmax5[k])
    
    w4.set_ylim(ymin4[k], ymax4[k])
        
    w1.set_title(r'$\mu =$' + mu[i])
    w5.set_xlabel(r'Intensity, cgs $\times$ 10${^7}$')

    w1.set_xscale('log')
    w2.set_xscale('log')
    w3.set_xscale('log')
    w4.set_xscale('log')
    w5.set_xscale('log')
    
    w1.set_yscale('log')
    w2.set_yscale('log')
    w3.set_yscale('log')
    w4.set_yscale('log')
    w5.set_yscale('log')

    if i == 0:

        leg1 = w1.legend(framealpha = 1, loc = 1, handletextpad = 1, prop = {'size': 7.5}, bbox_to_anchor = (0.95, 0.97))

        for obj in leg1.legendHandles: obj.set_linewidth(2.5)
            
        w1.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w2.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w3.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w4.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
        w5.set_ylabel(r'$N / N_\mathrm{tot} / \Delta$')
    
    if i == 4:

        w1.set_ylabel(str(w[j1]) + ' nm')
        w2.set_ylabel(str(w[j2]) + ' nm')
        w3.set_ylabel(str(w[j3]) + ' nm')
        w4.set_ylabel(str(w[j4]) + ' nm')
        w5.set_ylabel(str(w[j5]) + ' nm')
        
        w1.yaxis.set_label_position("right")
        w2.yaxis.set_label_position("right")
        w3.yaxis.set_label_position("right")
        w4.yaxis.set_label_position("right")
        w5.yaxis.set_label_position("right")

plt.savefig('./fig/intensity_hist_xlog_ylog.pdf', bbox_inches = 'tight')

plt.close('all')
